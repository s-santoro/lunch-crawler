# %%
# Imports
from luigi.contrib.spark import PySparkTask
from luigi.parameter import IntParameter, DateSecondParameter
from luigi import LocalTarget, Task, WrapperTask
import datetime
import pandas as pd
import re
from nltk.stem.cistem import Cistem
# %run Importer.ipynb

class Preprocessor(Task):

    # Date for Output-File prefix
    from datetime import date, timedelta
    date = DateSecondParameter(default=datetime.datetime.now())
    
    # Method to declare the Output-File
    def output(self):
        prefix = self.date.strftime("%Y-%m-%dT%H%M%S")
        return LocalTarget("data/%s_Preprocessor_out.csv" % prefix, format=UTF8)
    
    # Method to define the required Task (Importer)
    def requires(self):
        return Importer()


    # Preprocess the imported Data
    def run(self):
        df = pd.read_csv(self.input().path)
        output_df = pd.DataFrame(columns=('text', 'url', 'title', 'class'))
        
        # Preprocessing
        for index, document in df.iterrows():
            # Text Preprocessing
            text = self.toLowerCase(document.text)
            text = self.priceTagger(text)
            text = self.removeSpecialCharacters(text)
            text = self.removeSingleCharacters(text)
            text = self.removeMultiSpaces(text)
            text = self.stemText(text)
            text = self.removeStopWords(text)
            
            # Title Preprocessing
            title = self.toLowerCase(document.title)
            title = self.replaceUmlaut(title)
            title = self.removeSpecialCharacters(title)
            title = self.removeSingleCharacters(title)
            title = self.removeMultiSpaces(title)
            
            #Write rows for Output-File
            row = [text, document.url, title, document.Class]
            output_df.loc[index] = row
        
        # Write .csv-File
        print(output_df)
        with self.output().open("w") as out:
            output_df.to_csv(out, encoding="utf-8")
            
    
    # External Methods for preprocessing
    def toLowerCase(self, text):
        return text.lower()
    
    def priceTagger(self, text):
        # match following patterns with decimalpoint or comma, real rappen-values and chf,sfr,fr or .-:
        # _xxx.xx_chf
        # _xxx.xxchf
        text = re.sub(r' [0-9]{1,3}(\.|\,)[0-9](5|0) {0,1}(chf|sfr|fr|\.\-)', ' preis ', text)
        # match following patterns with chf,sfr,fr or .-:
        # _xxx_chf
        # _xxxchf
        text = re.sub(r' [0-9]{1,3} {0,1}(chf|sfr|fr|\.\-)', ' preis ', text)
        # match following patterns with decimalpoint or comma and real rappen-values:
        # xxx.xx
        # _xxx.xx
        # code smell because this pattern can also match dates (i.e 25.05 or 12.10)
        text = re.sub(r' [0-9]{1,3}(\.|\,)[0-9](5|0)[^0-9\.a-z] {0,1}', ' preis ', text)
        return text
        
    def removeSpecialCharacters(self, text):
        return re.sub(r'[^éàèÉÀÈäöüÄÖÜa-zA-Z0-9]+', ' ', str(text))
    
    def removeSingleCharacters(self, text):
        return re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    
    def removeMultiSpaces(self, text):
        return re.sub(r'\s+', ' ', text, flags=re.I)
    
    def stemText(self, text):
        stemmer = Cistem()
        return [stemmer.stem(word) for word in text.split()]
    
    def removeStopWords(self, words):
        # use own stopword list
        stop = pd.read_csv('stopwords_no_umlaute.txt', header=None)
        stop.columns = ['word']
        # convert list to set for word comparison
        stopwordSet = set(stop.word)
        wordsFiltered = []
        wordsRemoved = []
        for w in words:
            if w not in stopwordSet:
                wordsFiltered.append(w)
            if w in stopwordSet:
                wordsRemoved.append(w)

        #print("Removed words: %s" % wordsRemoved)
        #print("Percentage of removed words: %s" % (len(wordsRemoved)/len(words)*100))
        return wordsFiltered
    
    def replaceUmlaut(self, text):
        text = re.sub(r'ä', 'a', text)
        text = re.sub(r'ö', 'o', text)
        text = re.sub(r'ü', 'u', text)
        return text
        

pre = Preprocessor()
pre.run()
# Out:
#                                                   text  \
# 0    [bestell, hotli, 41, 71, 228, 66, 77, navigati...
# 1    [café, restaura, seefeld, zurich, hom, menu, a...
# 2    [café, restaura, seefeld, zurich, hom, menu, a...
# 3    [café, restaura, seefeld, zurich, hom, menu, a...
# 4    [café, restaura, seefeld, zurich, hom, menu, a...
# 5    [startsei, offnungszei, reservatio, dess, kaff...
# 6    [startsei, offnungszei, reservatio, dess, kaff...
# 7    [star, angebo, menu, onli, reservatio, offnung...
# 8    [wein, hauslieferung, feier, tisch, reservatio...
# 9    [menu, casa, rustica, illnauerstrass, 12, 8307...
# 10   [casa, villa, auftritt, langjahrig, erfahrung,...
# 11   [bun, winterprogramm, theaterjahr, 360, ansich...
# 12   [begi, typing, your, search, abov, press, retu...
# 13   [hom, anrei, kontak, auskunf, buchung, tischre...
# 14   [hom, anrei, kontak, auskunf, buchung, tischre...
# 15   [hom, anrei, kontak, auskunf, buchung, tischre...
# 16   [club, eve, restaura, restaura, men, kontak, r...
# 17   [menu, menu, gutburgerlich, schweiz, kuch, neb...
# 18   [seo, cms, g50plu, fischkuch, bahnhofli, rumik...
# 19   [fondu, beizli, portra, angebo, speisekar, kon...
# 20   [menu, mittag, menu, bes, tag, taglich, frisch...
# 21   [deutsch, il, postino, ristora, bar, italienis...
# 22   [montag, freitag, taglich, wechsel, mittagsger...
# 23   [hom, speisekar, speisekar, weinkar, bierkar, ...
# 24   [hom, speisekar, speisekar, weinkar, bierkar, ...
# 25   [imagi, menu, brunch, kontak, par, reservatio,...
# 26   [speisekar, menu, card, startsei, philosophie,...
# 27   [authentisch, aromatisch, anspruch, qualita, a...
# 28   [trank, spei, regio, hausgemach, pdf, angebots...
# 29   [reservier, ess, trink, wochenmenu, spar, rib,...
# ..                                                 ...
# 95   [offer, anlass, dreispitzwila, menu, mittagsme...
# 96   [menu, dreispitzwila, menu, mittagsmenu, offer...
# 97   [menuvorschlag, anlass, dreispitzwila, menu, m...
# 98   [mittagsmenu, dreispitzwila, menu, mittagsmenu...
# 99   [vorspei, sala, supp, menu, 1, montag, 11, 3, ...
# 100  [menukar, niess, all, sinn, terri, kalbsschwan...
# 101  [winnspiel, wochenmenu, schulermenu, spei, tra...
# 102  [menuvorschlag, grupp, bankett, menuvorschlag,...
# 103  [skip, to, navigatio, direk, inhal, engel, men...
# 104  [facebook, twitt, gplu, linkedi, telefo, 044, ...
# 105  [menukar, kar, klei, stal, tag, bes, produk, k...
# 106  [fago, restaura, café, bar, restaura, kuch, ta...
# 107  [fago, restaura, café, bar, restaura, kuch, ta...
# 108  [fago, restaura, café, bar, restaura, kuch, ta...
# 109  [wochenmenu, morg, prei, prei, 1, kaffee, 1, g...
# 110  [hom, hom, spei, trank, sellschaf, aktuell, ga...
# 111  [hom, hom, spei, trank, sellschaf, aktuell, ga...
# 112  [restaura, freihof, buttiko, rainbow, smok, ba...
# 113  [kostlich, full, knusprig, panier, cordo, bleu...
# 114  [hom, pag, altstadtbeiz, speisekar, vorspei, h...
# 115  [hom, pag, altstadtbeiz, speisekar, vorspei, h...
# 116  [hom, pag, altstadtbeiz, speisekar, vorspei, h...
# 117  [hom, pag, altstadtbeiz, speisekar, vorspei, h...
# 118  [navigatio, uberspring, hom, reservatio, konta...
# 119  [restaura, hotel, download, galerie, tag, menu...
# 120  [7, 00, normal, chf, mouss, au, chocola, prei,...
# 121  [schweiz, kuch, prei, alpl, makkaroni, prei, d...
# 124  http://www.jaegerstuebli-binningen.ch/speiseka...
#
#                                                  title class
# 0            menu cafe gschwend st gallen gschwind is      0
# 1    menu bistro und italienische spezialitaten in ...     0
# 2    apéro abendessen apéro und italienische kuche ...     0
# 3    japanische kuche in zurich seefeld degustation...     0
# 4    lunch take away restaurant in zurich seefeld c...     0
# 5    tagesmenu hier bekommen sie den besten kaffee ...     0
# 6    menu der woche hier bekommen sie den besten ka...     0
# 7    angebot menu restaurant calix pfister center suhr     0
# 8                    tagesmenu pizzeria capri adliswil     0
# 9                                               menues     0
# 10                                     hochzeiten menu     0
# 11   restaurant in der altstadt von winterthur casi...     0
# 12                                    produkte english     0
# 13                                      beat betschart     0
# 14                                        beat heinzer     0
# 15                                       carlo heinzer     0
# 16   restaurant und kantine am escherwyssplatz rest...     0
# 17                              menu restaurant falken     0
# 18                                      menuvorschlage     0
# 19                                        fonduebeizli     0
# 20                           menu restaurant il locale     0
# 21   il postino ristorante bar speisen und getranke...     0
# 22                                                menu     0
# 23               alle speisekarten restaurant im speck     0
# 24                     whiskykarte restaurant im speck     0
# 25        das menu der imagine restaurant am hb zurich     0
# 26                           die speisekarte menu card     0
# 27                                  kuche speisekarte      0
# 28                              getranke speisen si no     0
# 29                                wochenmenu isebahnli     0
# ..                                                 ...   ...
# 95       unsere offerte fur ihren anlass dreispitzwila     1
# 96                                 menus dreispitzwila     1
# 97            menuvorschlage fur anlasse dreispitzwila     1
# 98                           mittagsmenu dreispitzwila     1
# 99                                    wochenmenu dukes     1
# 100                           menukarte eder eichmuhle     1
# 101                           schulermenus el sombrero     1
# 102                    menuvorschlage restaurant engel     1
# 103                     menu speisekarte gasthof engel     1
# 104                       menu vom tag enjoy schlieren     1
# 105                   restaurant essort bern menukarte     1
# 106                     kuche fago restaurant café bar     1
# 107                     kuche fago restaurant café bar     1
# 108                     kuche fago restaurant café bar     1
# 109                                     speisen feedys     1
# 110                                               home     1
# 111                                               home     1
# 112  tagesmenue rest freihof buttikon rainbow smoke...     1
# 113                                 saison speisekarte     1
# 114                  homepage restaurant frohsinn bern     1
# 115                  homepage restaurant frohsinn bern     1
# 116                  homepage restaurant frohsinn bern     1
# 117                  homepage restaurant frohsinn bern     1
# 118  das restaurant am zurichsee mit grandiosem wei...     1
# 119               mittagsmenus hotel brauerei frohsinn     1
# 120                                    dessert im guet     1
# 121                                    schweizer kuche     1
# 122          penne broccoli und schinken italian place     1
# 123                      ravioli polenta italian place     1
# 124                                menus ab 2 personen     1
#
# [125 rows x 4 columns]

# %% [markdown]
# Preis-Regex werden verwendet, um effektive Preise auf das Wort 'preis' zu mappen.
# Dies ist nützlich, indem bei der späteren Klassifizierung nach dem Wort 'preis' und nicht nach
# effektiven Frankenbeträgen gesucht werden kann.
#
# Die unteren Muster von Preisen wurden mit den Regex formuliert
# - _xxx.xx chf
# - _xxx.xxchf
# - _xxx chf
# - _xxxchf
# - _xxx.xx
# - Die Muster folgen folgender Konvention:
#     - Es kann entweder ein Dezimalpunkt oder ein Komma als Separator verwendet werden
#     - Die Preise gehen von 00.00 bis 999.95
#     - Es werden nur Preise erkannt, die einen realen Rappenbetrag präsentieren
#     - Es können chf, sfr, fr oder .- als Abkürzungen für Geldbeträge verwendet werden
#     - Preise ohne Abkürzungen sind auch möglich, sofern sie die anderen Konventionen berücksichtigen
#     - Der Bodenstrich soll ein Leerzeichen präsentieren
